# %% [markdown]
# ### pakage import

# %%
import os
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
import torchvision.transforms as tt
from torch.utils.data import DataLoader
from torchvision.utils import make_grid,save_image
import cv2
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Download dataset

# %% [markdown]
# - Dataset url : https://www.kaggle.com/datasets/kvpratama/pokemon-images-dataset
# - Download the dataset(74M) and place it into your local path

# %%
path = "/content/drive/MyDrive/pokemon_ds" # customize your image folder path

# %%
os.listdir(path)
# Out:
# ['pokemon_jpg']

# %%
image_size = 64
batch_size = 64
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

train_ds = ImageFolder(path,transform=tt.Compose([
    tt.Resize(image_size),
    tt.CenterCrop(image_size),
    tt.ToTensor(),
    tt.Normalize(*stats),
    tt.RandomHorizontalFlip(p=0.5)
]))

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

# %%
def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(train_dl)

# %%
def get_default_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

# %%
def to_device(data,device):
    if isinstance(data,(list,tuple)):
        return [to_device(x,device) for x in data]
    return data.to(device, non_blocking=True)

# %%
class DeviceDataLoader():
    def __init__(self,dl,device):
        self.dl = dl
        self.device = device
    def __iter__(self):
        for b in self.dl:
            yield to_device(b,device)
    def __len__(self):
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %%
discriminator = nn.Sequential(
    nn.Conv2d(3,64,kernel_size=4,stride=2,padding=1,bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2,inplace=True),
    
    nn.Conv2d(64,128,kernel_size=4,stride=2,padding=1,bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2,inplace=True),
    
    nn.Conv2d(128,256,kernel_size=4,stride=2,padding=1,bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2,inplace=True),
    
    nn.Conv2d(256,512,kernel_size=4,stride=2,padding=1,bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2,inplace=True),
    
    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    
    nn.Flatten(),
    nn.Sigmoid()
)

# %%
discriminator = to_device(discriminator,device)

# %%
latent_size = 128
generator = nn.Sequential(
    nn.ConvTranspose2d(latent_size,512,kernel_size=4,stride=1,padding=0,bias = False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    
    nn.ConvTranspose2d(512,256,kernel_size=4,stride=2,padding=1,bias = False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    
    nn.ConvTranspose2d(256,128,kernel_size=4,stride=2,padding=1,bias = False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    
    nn.ConvTranspose2d(128,64,kernel_size=4,stride=2,padding=1,bias = False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    
    nn.ConvTranspose2d(64,3,kernel_size=4,stride=2,padding=1,bias = False),
    nn.Tanh()
)

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([64, 3, 64, 64])

# %%
generator = to_device(generator,device)

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    # real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_targets = torch.cuda.FloatTensor(real_images.size(0), 1).fill_(0.9)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    # fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_targets = torch.cuda.FloatTensor(fake_images.size(0), 1).fill_(0.1)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt):
    opt.zero_grad()
    latent = torch.randn(batch_size,latent_size,1,1,device=device)
    fake_images = generator(latent)
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size,1,device = device)
    loss = F.binary_cross_entropy(preds,targets)
    loss.backward()
    opt.step()
    return loss.item()

# %%
sample_dir = '/content/drive/MyDrive/generated'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = '{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# %%
save_samples(0, fixed_latent)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving 0000.png

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in train_dl:
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.0002
epochs = 1000
history = fit(epochs, lr)
# Out:
# Epoch [1/1000], loss_g: 5.3468, loss_d: 1.1165, real_score: 0.6376, fake_score: 0.0071
# Saving 0001.png
# Epoch [2/1000], loss_g: 1.9410, loss_d: 0.7023, real_score: 0.9523, fake_score: 0.1042
# Saving 0002.png
# Epoch [3/1000], loss_g: 2.1349, loss_d: 0.6819, real_score: 0.8807, fake_score: 0.1364
# Saving 0003.png
# Epoch [4/1000], loss_g: 7.5958, loss_d: 1.2681, real_score: 0.6235, fake_score: 0.0007
# Saving 0004.png
# Epoch [5/1000], loss_g: 3.5050, loss_d: 0.6580, real_score: 0.8952, fake_score: 0.1150
# Saving 0005.png
# Epoch [6/1000], loss_g: 2.9835, loss_d: 0.6648, real_score: 0.8702, fake_score: 0.0997
# Saving 0006.png
# Epoch [7/1000], loss_g: 3.7264, loss_d: 0.8419, real_score: 0.9623, fake_score: 0.3027
# Saving 0007.png
# Epoch [8/1000], loss_g: 2.7578, loss_d: 0.7150, real_score: 0.8061, fake_score: 0.1809
# Saving 0008.png
# Epoch [9/1000], loss_g: 2.9461, loss_d: 0.8997, real_score: 0.9184, fake_score: 0.3999
# Saving 0009.png
# Epoch [10/1000], loss_g: 4.5582, loss_d: 1.0940, real_score: 0.8845, fake_score: 0.5263
# Saving 0010.png
# Epoch [11/1000], loss_g: 2.3730, loss_d: 0.9893, real_score: 0.9059, fake_score: 0.4529
# Saving 0011.png
# Epoch [12/1000], loss_g: 2.4128, loss_d: 0.7609, real_score: 0.7464, fake_score: 0.1497
# Saving 0012.png
# Epoch [13/1000], loss_g: 2.6642, loss_d: 0.9122, real_score: 0.6255, fake_score: 0.1636
# Saving 0013.png
# Epoch [14/1000], loss_g: 0.7337, loss_d: 1.0464, real_score: 0.5085, fake_score: 0.0891
# Saving 0014.png
# Epoch [15/1000], loss_g: 1.8038, loss_d: 0.8009, real_score: 0.6948, fake_score: 0.1323
# Saving 0015.png
# Epoch [16/1000], loss_g: 2.2630, loss_d: 0.8104, real_score: 0.6825, fake_score: 0.1020
# Saving 0016.png
# Epoch [17/1000], loss_g: 2.6146, loss_d: 1.6800, real_score: 0.2878, fake_score: 0.0111
# Saving 0017.png
# Epoch [18/1000], loss_g: 2.0757, loss_d: 0.9801, real_score: 0.5552, fake_score: 0.0508
# Saving 0018.png
# Epoch [19/1000], loss_g: 2.8546, loss_d: 0.9633, real_score: 0.9086, fake_score: 0.4324
# Saving 0019.png
# Epoch [20/1000], loss_g: 2.0817, loss_d: 0.9244, real_score: 0.7738, fake_score: 0.3576
# Saving 0020.png
# Epoch [21/1000], loss_g: 1.3223, loss_d: 0.9581, real_score: 0.6074, fake_score: 0.2327
# Saving 0021.png
# Epoch [22/1000], loss_g: 3.3445, loss_d: 0.8845, real_score: 0.7973, fake_score: 0.3468
# Saving 0022.png
# Epoch [23/1000], loss_g: 2.1838, loss_d: 0.9875, real_score: 0.7054, fake_score: 0.3698
# Saving 0023.png
# Epoch [24/1000], loss_g: 2.9325, loss_d: 0.7977, real_score: 0.8191, fake_score: 0.2746
# Saving 0024.png
# Epoch [25/1000], loss_g: 2.6149, loss_d: 0.8562, real_score: 0.7456, fake_score: 0.2875
# Saving 0025.png
# Epoch [26/1000], loss_g: 0.9980, loss_d: 1.3211, real_score: 0.3812, fake_score: 0.0862
# Saving 0026.png
# Epoch [27/1000], loss_g: 1.6015, loss_d: 1.0439, real_score: 0.5165, fake_score: 0.0739
# Saving 0027.png
# Epoch [28/1000], loss_g: 3.4617, loss_d: 0.9351, real_score: 0.7947, fake_score: 0.3704
# Saving 0028.png
# Epoch [29/1000], loss_g: 1.5543, loss_d: 1.1311, real_score: 0.4630, fake_score: 0.1050
# Saving 0029.png
# Epoch [30/1000], loss_g: 2.0837, loss_d: 0.8335, real_score: 0.6935, fake_score: 0.1913
# Saving 0030.png
# Epoch [31/1000], loss_g: 2.9892, loss_d: 1.0076, real_score: 0.8484, fake_score: 0.4619
# Saving 0031.png
# Epoch [32/1000], loss_g: 1.7004, loss_d: 0.9220, real_score: 0.7231, fake_score: 0.3207
# Saving 0032.png
# Epoch [33/1000], loss_g: 2.6047, loss_d: 0.9197, real_score: 0.7594, fake_score: 0.3408
# Saving 0033.png
# Epoch [34/1000], loss_g: 2.4473, loss_d: 0.8948, real_score: 0.7914, fake_score: 0.3560
# Saving 0034.png
# Epoch [35/1000], loss_g: 1.4719, loss_d: 1.2704, real_score: 0.4283, fake_score: 0.0431
# Saving 0035.png
# Epoch [36/1000], loss_g: 1.5622, loss_d: 1.3868, real_score: 0.3741, fake_score: 0.0296
# Saving 0036.png
# Epoch [37/1000], loss_g: 2.1742, loss_d: 0.9623, real_score: 0.6652, fake_score: 0.3122
# Saving 0037.png
# Epoch [38/1000], loss_g: 2.6652, loss_d: 0.8584, real_score: 0.8145, fake_score: 0.3348
# Saving 0038.png
# Epoch [39/1000], loss_g: 1.9937, loss_d: 0.9328, real_score: 0.6433, fake_score: 0.2277
# Saving 0039.png
# Epoch [40/1000], loss_g: 2.7169, loss_d: 0.9811, real_score: 0.8572, fake_score: 0.4418
# Saving 0040.png
# Epoch [41/1000], loss_g: 0.8387, loss_d: 2.1419, real_score: 0.1646, fake_score: 0.0225
# Saving 0041.png
# Epoch [42/1000], loss_g: 2.0285, loss_d: 0.8188, real_score: 0.7444, fake_score: 0.2450
# Saving 0042.png
# Epoch [43/1000], loss_g: 2.2229, loss_d: 0.9275, real_score: 0.7357, fake_score: 0.3448
# Saving 0043.png
# Epoch [44/1000], loss_g: 1.3497, loss_d: 1.3142, real_score: 0.3922, fake_score: 0.0845
# Saving 0044.png
# Epoch [45/1000], loss_g: 3.5273, loss_d: 1.0722, real_score: 0.8806, fake_score: 0.4991
# Saving 0045.png
# Epoch [46/1000], loss_g: 2.5630, loss_d: 0.9391, real_score: 0.7011, fake_score: 0.3210
# Saving 0046.png
# Epoch [47/1000], loss_g: 2.0291, loss_d: 0.9692, real_score: 0.6778, fake_score: 0.3235
# Saving 0047.png
# Epoch [48/1000], loss_g: 1.6925, loss_d: 0.9468, real_score: 0.6499, fake_score: 0.2798
# Saving 0048.png
# Epoch [49/1000], loss_g: 1.1573, loss_d: 1.0430, real_score: 0.5141, fake_score: 0.1368
# Saving 0049.png
# Epoch [50/1000], loss_g: 3.5810, loss_d: 1.4087, real_score: 0.9195, fake_score: 0.6463
# Saving 0050.png
# Epoch [51/1000], loss_g: 1.2410, loss_d: 1.0304, real_score: 0.5218, fake_score: 0.1094
# Saving 0051.png
# Epoch [52/1000], loss_g: 2.0420, loss_d: 0.9043, real_score: 0.6855, fake_score: 0.2537
# Saving 0052.png
# Epoch [53/1000], loss_g: 0.8982, loss_d: 1.2581, real_score: 0.4138, fake_score: 0.0790
# Saving 0053.png
# Epoch [54/1000], loss_g: 2.3479, loss_d: 0.8731, real_score: 0.7671, fake_score: 0.2996
# Saving 0054.png
# Epoch [55/1000], loss_g: 2.4688, loss_d: 0.9750, real_score: 0.7515, fake_score: 0.3833
# Saving 0055.png
# Epoch [56/1000], loss_g: 3.0960, loss_d: 1.0939, real_score: 0.8795, fake_score: 0.4971
# Saving 0056.png
# Epoch [57/1000], loss_g: 2.3527, loss_d: 0.9311, real_score: 0.7388, fake_score: 0.3514
# Saving 0057.png
# Epoch [58/1000], loss_g: 1.7958, loss_d: 0.9570, real_score: 0.6806, fake_score: 0.3206
# Saving 0058.png
# Epoch [59/1000], loss_g: 1.5727, loss_d: 0.9502, real_score: 0.6064, fake_score: 0.2066
# Saving 0059.png
# Epoch [60/1000], loss_g: 1.4365, loss_d: 1.0521, real_score: 0.5183, fake_score: 0.1179
# Saving 0060.png
# Epoch [61/1000], loss_g: 1.5155, loss_d: 1.5304, real_score: 0.3205, fake_score: 0.0361
# Saving 0061.png
# Epoch [62/1000], loss_g: 2.9341, loss_d: 1.0485, real_score: 0.8236, fake_score: 0.4732
# Saving 0062.png
# Epoch [63/1000], loss_g: 1.9444, loss_d: 0.8135, real_score: 0.7299, fake_score: 0.1933
# Saving 0063.png
# Epoch [64/1000], loss_g: 1.6120, loss_d: 1.8386, real_score: 0.2514, fake_score: 0.0197
# Saving 0064.png
# Epoch [65/1000], loss_g: 1.3918, loss_d: 1.0066, real_score: 0.5684, fake_score: 0.2081
# Saving 0065.png
# Epoch [66/1000], loss_g: 2.0082, loss_d: 1.0571, real_score: 0.6236, fake_score: 0.3252
# Saving 0066.png
# Epoch [67/1000], loss_g: 2.3607, loss_d: 1.1370, real_score: 0.7251, fake_score: 0.4764
# Saving 0067.png
# Epoch [68/1000], loss_g: 2.7953, loss_d: 1.1032, real_score: 0.7809, fake_score: 0.4870
# Saving 0068.png
# Epoch [69/1000], loss_g: 1.5140, loss_d: 1.0244, real_score: 0.5709, fake_score: 0.2263
# Saving 0069.png
# Epoch [70/1000], loss_g: 1.7403, loss_d: 0.8412, real_score: 0.7210, fake_score: 0.2388
# Saving 0070.png
# Epoch [71/1000], loss_g: 2.1847, loss_d: 0.9167, real_score: 0.8235, fake_score: 0.3784
# Saving 0071.png
# Epoch [72/1000], loss_g: 1.6963, loss_d: 0.9493, real_score: 0.6629, fake_score: 0.2830
# Saving 0072.png
# Epoch [73/1000], loss_g: 2.7736, loss_d: 1.0711, real_score: 0.8054, fake_score: 0.4700
# Saving 0073.png
# Epoch [74/1000], loss_g: 1.2239, loss_d: 1.7647, real_score: 0.2594, fake_score: 0.0387
# Saving 0074.png
# Epoch [75/1000], loss_g: 3.6241, loss_d: 1.1280, real_score: 0.8813, fake_score: 0.5275
# Saving 0075.png
# Epoch [76/1000], loss_g: 1.8977, loss_d: 0.9857, real_score: 0.5676, fake_score: 0.1388
# Saving 0076.png
# Epoch [77/1000], loss_g: 3.7323, loss_d: 1.2271, real_score: 0.8853, fake_score: 0.5775
# Saving 0077.png
# Epoch [78/1000], loss_g: 3.3954, loss_d: 1.0191, real_score: 0.7741, fake_score: 0.4217
# Saving 0078.png
# Epoch [79/1000], loss_g: 1.9415, loss_d: 0.9216, real_score: 0.7073, fake_score: 0.2770
# Saving 0079.png
# Epoch [80/1000], loss_g: 2.1193, loss_d: 0.9252, real_score: 0.7271, fake_score: 0.3211
# Saving 0080.png
# Epoch [81/1000], loss_g: 1.6946, loss_d: 0.9171, real_score: 0.6682, fake_score: 0.2430
# Saving 0081.png
# Epoch [82/1000], loss_g: 3.4437, loss_d: 1.0599, real_score: 0.7853, fake_score: 0.4569
# Saving 0082.png
# Epoch [83/1000], loss_g: 1.9474, loss_d: 0.9033, real_score: 0.6971, fake_score: 0.2562
# Saving 0083.png
# Epoch [84/1000], loss_g: 2.0348, loss_d: 0.8346, real_score: 0.7873, fake_score: 0.2925
# Saving 0084.png
# Epoch [85/1000], loss_g: 1.4219, loss_d: 0.9535, real_score: 0.6013, fake_score: 0.1685
# Saving 0085.png
# Epoch [86/1000], loss_g: 3.4932, loss_d: 1.0755, real_score: 0.9197, fake_score: 0.5020
# Saving 0086.png
# Epoch [87/1000], loss_g: 2.6920, loss_d: 0.8873, real_score: 0.8016, fake_score: 0.3221
# Saving 0087.png
# Epoch [88/1000], loss_g: 2.2226, loss_d: 0.8825, real_score: 0.8168, fake_score: 0.3455
# Saving 0088.png
# Epoch [89/1000], loss_g: 2.5487, loss_d: 1.0998, real_score: 0.8945, fake_score: 0.5132
# Saving 0089.png
# Epoch [90/1000], loss_g: 2.6346, loss_d: 0.9399, real_score: 0.8414, fake_score: 0.3909
# Saving 0090.png
# Epoch [91/1000], loss_g: 2.0303, loss_d: 0.8594, real_score: 0.6724, fake_score: 0.1649
# Saving 0091.png
# Epoch [92/1000], loss_g: 1.8927, loss_d: 1.0391, real_score: 0.5454, fake_score: 0.0773
# Saving 0092.png
# Epoch [93/1000], loss_g: 1.8160, loss_d: 0.8463, real_score: 0.7019, fake_score: 0.1992
# Saving 0093.png
# Epoch [94/1000], loss_g: 1.4970, loss_d: 1.0333, real_score: 0.5424, fake_score: 0.1623
# Saving 0094.png
# Epoch [95/1000], loss_g: 2.4905, loss_d: 1.0737, real_score: 0.8195, fake_score: 0.4738
# Saving 0095.png
# Epoch [96/1000], loss_g: 1.6600, loss_d: 1.3137, real_score: 0.4079, fake_score: 0.0465
# Saving 0096.png
# Epoch [97/1000], loss_g: 2.2388, loss_d: 0.9058, real_score: 0.6981, fake_score: 0.2573
# Saving 0097.png
# Epoch [98/1000], loss_g: 1.5073, loss_d: 1.0356, real_score: 0.5743, fake_score: 0.1439
# Saving 0098.png
# Epoch [99/1000], loss_g: 1.1906, loss_d: 0.8733, real_score: 0.6814, fake_score: 0.2008
# Saving 0099.png
# Epoch [100/1000], loss_g: 1.6579, loss_d: 0.9051, real_score: 0.6415, fake_score: 0.1689
# Saving 0100.png
# Epoch [101/1000], loss_g: 1.5297, loss_d: 0.8962, real_score: 0.6466, fake_score: 0.1672
# Saving 0101.png
# Epoch [102/1000], loss_g: 2.8796, loss_d: 0.8760, real_score: 0.8046, fake_score: 0.3112
# Saving 0102.png
# Epoch [103/1000], loss_g: 1.6256, loss_d: 0.8065, real_score: 0.7357, fake_score: 0.1787
# Saving 0103.png
# Epoch [104/1000], loss_g: 1.6621, loss_d: 0.8935, real_score: 0.6626, fake_score: 0.1668
# Saving 0104.png
# Epoch [105/1000], loss_g: 3.5804, loss_d: 0.8950, real_score: 0.8427, fake_score: 0.3574
# Saving 0105.png
# Epoch [106/1000], loss_g: 2.8336, loss_d: 0.8755, real_score: 0.8054, fake_score: 0.3218
# Saving 0106.png
# Epoch [107/1000], loss_g: 1.5538, loss_d: 1.1557, real_score: 0.4794, fake_score: 0.0629
# Saving 0107.png
# Epoch [108/1000], loss_g: 1.6801, loss_d: 0.9052, real_score: 0.6542, fake_score: 0.1717
# Saving 0108.png
# Epoch [109/1000], loss_g: 2.4366, loss_d: 0.8039, real_score: 0.8032, fake_score: 0.2340
# Saving 0109.png
# Epoch [110/1000], loss_g: 2.3340, loss_d: 0.8261, real_score: 0.8381, fake_score: 0.3003
# Saving 0110.png
# Epoch [111/1000], loss_g: 1.7687, loss_d: 0.8353, real_score: 0.6917, fake_score: 0.1341
# Saving 0111.png
# Epoch [112/1000], loss_g: 2.3125, loss_d: 0.8301, real_score: 0.7209, fake_score: 0.1629
# Saving 0112.png
# Epoch [113/1000], loss_g: 3.5955, loss_d: 0.9347, real_score: 0.9020, fake_score: 0.3833
# Saving 0113.png
# Epoch [114/1000], loss_g: 2.2085, loss_d: 0.8977, real_score: 0.6371, fake_score: 0.0969
# Saving 0114.png
# Epoch [115/1000], loss_g: 3.8732, loss_d: 0.9949, real_score: 0.8490, fake_score: 0.4334
# Saving 0115.png
# Epoch [116/1000], loss_g: 2.0717, loss_d: 0.8661, real_score: 0.7090, fake_score: 0.2215
# Saving 0116.png
# Epoch [117/1000], loss_g: 3.7622, loss_d: 1.0693, real_score: 0.9066, fake_score: 0.4740
# Saving 0117.png
# Epoch [118/1000], loss_g: 2.0503, loss_d: 0.8099, real_score: 0.8119, fake_score: 0.2479
# Saving 0118.png
# Epoch [119/1000], loss_g: 1.5783, loss_d: 0.8507, real_score: 0.6754, fake_score: 0.1507
# Saving 0119.png
# Epoch [120/1000], loss_g: 2.6731, loss_d: 0.7713, real_score: 0.8623, fake_score: 0.2416
# Saving 0120.png
# Epoch [121/1000], loss_g: 1.8775, loss_d: 0.7997, real_score: 0.7693, fake_score: 0.1936
# Saving 0121.png
# Epoch [122/1000], loss_g: 1.4468, loss_d: 1.0122, real_score: 0.5528, fake_score: 0.0671
# Saving 0122.png
# Epoch [123/1000], loss_g: 3.4756, loss_d: 0.9478, real_score: 0.8552, fake_score: 0.3906
# Saving 0123.png
# Epoch [124/1000], loss_g: 3.1074, loss_d: 0.8914, real_score: 0.8406, fake_score: 0.3444
# Saving 0124.png
# Epoch [125/1000], loss_g: 2.2707, loss_d: 0.7542, real_score: 0.7961, fake_score: 0.1593
# Saving 0125.png
# Epoch [126/1000], loss_g: 1.9797, loss_d: 0.8677, real_score: 0.6702, fake_score: 0.0948
# Saving 0126.png
# Epoch [127/1000], loss_g: 1.7061, loss_d: 1.1306, real_score: 0.5206, fake_score: 0.0346
# Saving 0127.png
# Epoch [128/1000], loss_g: 2.0186, loss_d: 0.8221, real_score: 0.7651, fake_score: 0.2311
# Saving 0128.png
# Epoch [129/1000], loss_g: 1.2776, loss_d: 0.8963, real_score: 0.6382, fake_score: 0.0926
# Saving 0129.png
# Epoch [130/1000], loss_g: 2.1551, loss_d: 0.7994, real_score: 0.7641, fake_score: 0.1941
# Saving 0130.png
# Epoch [131/1000], loss_g: 2.7570, loss_d: 0.8201, real_score: 0.8009, fake_score: 0.2478
# Saving 0131.png
# Epoch [132/1000], loss_g: 1.3260, loss_d: 0.8448, real_score: 0.6734, fake_score: 0.1173
# Saving 0132.png
# Epoch [133/1000], loss_g: 2.0697, loss_d: 0.7734, real_score: 0.7530, fake_score: 0.1405
# Saving 0133.png
# Epoch [134/1000], loss_g: 2.1476, loss_d: 0.8267, real_score: 0.8347, fake_score: 0.2705
# Saving 0134.png
# Epoch [135/1000], loss_g: 4.1870, loss_d: 1.0001, real_score: 0.9067, fake_score: 0.4387
# Saving 0135.png
# Epoch [136/1000], loss_g: 1.9189, loss_d: 0.9028, real_score: 0.6514, fake_score: 0.0821
# Saving 0136.png
# Epoch [137/1000], loss_g: 2.5469, loss_d: 0.8334, real_score: 0.8615, fake_score: 0.2967
# Saving 0137.png
# Epoch [138/1000], loss_g: 2.0511, loss_d: 0.8036, real_score: 0.7487, fake_score: 0.1751
# Saving 0138.png
# Epoch [139/1000], loss_g: 1.7988, loss_d: 0.8399, real_score: 0.7076, fake_score: 0.1651
# Saving 0139.png
# Epoch [140/1000], loss_g: 1.9251, loss_d: 0.7781, real_score: 0.7533, fake_score: 0.1382
# Saving 0140.png
# Epoch [141/1000], loss_g: 2.5284, loss_d: 0.7738, real_score: 0.7791, fake_score: 0.1693
# Saving 0141.png
# Epoch [142/1000], loss_g: 1.9853, loss_d: 1.0012, real_score: 0.5739, fake_score: 0.0710
# Saving 0142.png
# Epoch [143/1000], loss_g: 2.2218, loss_d: 0.7742, real_score: 0.7838, fake_score: 0.1872
# Saving 0143.png
# Epoch [144/1000], loss_g: 1.9912, loss_d: 0.7639, real_score: 0.7565, fake_score: 0.0863
# Saving 0144.png
# Epoch [145/1000], loss_g: 1.7514, loss_d: 0.7436, real_score: 0.7919, fake_score: 0.1512
# Saving 0145.png
# Epoch [146/1000], loss_g: 2.6533, loss_d: 0.7443, real_score: 0.8488, fake_score: 0.1960
# Saving 0146.png
# Epoch [147/1000], loss_g: 1.8707, loss_d: 0.7957, real_score: 0.7241, fake_score: 0.1216
# Saving 0147.png
# Epoch [148/1000], loss_g: 3.4054, loss_d: 0.8009, real_score: 0.8912, fake_score: 0.2931
# Saving 0148.png
# Epoch [149/1000], loss_g: 3.1908, loss_d: 0.7480, real_score: 0.9036, fake_score: 0.2222
# Saving 0149.png
# Epoch [150/1000], loss_g: 1.8859, loss_d: 0.7624, real_score: 0.7600, fake_score: 0.1131
# Saving 0150.png
# Epoch [151/1000], loss_g: 5.1060, loss_d: 1.1211, real_score: 0.9499, fake_score: 0.4979
# Saving 0151.png
# Epoch [152/1000], loss_g: 2.6509, loss_d: 0.8806, real_score: 0.7569, fake_score: 0.2460
# Saving 0152.png
# Epoch [153/1000], loss_g: 2.1533, loss_d: 0.8436, real_score: 0.7186, fake_score: 0.1700
# Saving 0153.png
# Epoch [154/1000], loss_g: 2.6278, loss_d: 0.7715, real_score: 0.8468, fake_score: 0.2128
# Saving 0154.png
# Epoch [155/1000], loss_g: 2.5492, loss_d: 0.7325, real_score: 0.8203, fake_score: 0.1603
# Saving 0155.png
# Epoch [156/1000], loss_g: 1.8129, loss_d: 0.7552, real_score: 0.7598, fake_score: 0.1282
# Saving 0156.png
# Epoch [157/1000], loss_g: 2.0773, loss_d: 0.7326, real_score: 0.8646, fake_score: 0.1758
# Saving 0157.png
# Epoch [158/1000], loss_g: 2.0894, loss_d: 0.7441, real_score: 0.8413, fake_score: 0.1922
# Saving 0158.png
# Epoch [159/1000], loss_g: 2.4508, loss_d: 0.7213, real_score: 0.8565, fake_score: 0.1787
# Saving 0159.png
# Epoch [160/1000], loss_g: 2.2703, loss_d: 0.7095, real_score: 0.8506, fake_score: 0.1601
# Saving 0160.png
# Epoch [161/1000], loss_g: 1.8762, loss_d: 0.7875, real_score: 0.7283, fake_score: 0.0884
# Saving 0161.png
# Epoch [162/1000], loss_g: 2.7105, loss_d: 0.7445, real_score: 0.9021, fake_score: 0.2316
# Saving 0162.png
# Epoch [163/1000], loss_g: 1.9373, loss_d: 0.7016, real_score: 0.8502, fake_score: 0.1216
# Saving 0163.png
# Epoch [164/1000], loss_g: 2.8919, loss_d: 0.7463, real_score: 0.8955, fake_score: 0.2327
# Saving 0164.png
# Epoch [165/1000], loss_g: 2.0200, loss_d: 1.1670, real_score: 0.8034, fake_score: 0.4851
# Saving 0165.png
# Epoch [166/1000], loss_g: 2.6771, loss_d: 0.9056, real_score: 0.7642, fake_score: 0.3095
# Saving 0166.png
# Epoch [167/1000], loss_g: 2.1280, loss_d: 0.7766, real_score: 0.7524, fake_score: 0.1264
# Saving 0167.png
# Epoch [168/1000], loss_g: 2.8885, loss_d: 0.7469, real_score: 0.8742, fake_score: 0.2105
# Saving 0168.png
# Epoch [169/1000], loss_g: 2.2113, loss_d: 0.7546, real_score: 0.8700, fake_score: 0.2263
# Saving 0169.png
# Epoch [170/1000], loss_g: 4.0066, loss_d: 0.8867, real_score: 0.9346, fake_score: 0.3554
# Saving 0170.png
# Epoch [171/1000], loss_g: 1.7772, loss_d: 0.7195, real_score: 0.8498, fake_score: 0.1643
# Saving 0171.png
# Epoch [172/1000], loss_g: 2.2902, loss_d: 0.7075, real_score: 0.8225, fake_score: 0.1083
# Saving 0172.png
# Epoch [173/1000], loss_g: 2.0044, loss_d: 0.7180, real_score: 0.8146, fake_score: 0.1035
# Saving 0173.png
# Epoch [174/1000], loss_g: 2.9090, loss_d: 0.7180, real_score: 0.9119, fake_score: 0.1973
# Saving 0174.png
# Epoch [175/1000], loss_g: 2.3000, loss_d: 0.7014, real_score: 0.8358, fake_score: 0.1281
# Saving 0175.png
# Epoch [176/1000], loss_g: 2.2959, loss_d: 0.7192, real_score: 0.8616, fake_score: 0.1918
# Saving 0176.png
# Epoch [177/1000], loss_g: 2.2464, loss_d: 0.7174, real_score: 0.8556, fake_score: 0.1544
# Saving 0177.png
# Epoch [178/1000], loss_g: 2.7185, loss_d: 0.6992, real_score: 0.8980, fake_score: 0.1602
# Saving 0178.png
# Epoch [179/1000], loss_g: 4.5186, loss_d: 0.8983, real_score: 0.9530, fake_score: 0.3689
# Saving 0179.png
# Epoch [180/1000], loss_g: 2.2163, loss_d: 0.7034, real_score: 0.8242, fake_score: 0.1042
# Saving 0180.png
# Epoch [181/1000], loss_g: 2.7653, loss_d: 0.7123, real_score: 0.8787, fake_score: 0.1860
# Saving 0181.png
# Epoch [182/1000], loss_g: 2.5337, loss_d: 0.6901, real_score: 0.8558, fake_score: 0.1118
# Saving 0182.png
# Epoch [183/1000], loss_g: 2.5611, loss_d: 0.7156, real_score: 0.8548, fake_score: 0.1649
# Saving 0183.png
# Epoch [184/1000], loss_g: 1.8746, loss_d: 0.8166, real_score: 0.7052, fake_score: 0.0460
# Saving 0184.png
# Epoch [185/1000], loss_g: 2.1845, loss_d: 0.7108, real_score: 0.8032, fake_score: 0.1219
# Saving 0185.png
# Epoch [186/1000], loss_g: 2.4367, loss_d: 0.6921, real_score: 0.8806, fake_score: 0.1445
# Saving 0186.png
# Epoch [187/1000], loss_g: 2.3866, loss_d: 0.7004, real_score: 0.8672, fake_score: 0.1661
# Saving 0187.png
# Epoch [188/1000], loss_g: 2.6484, loss_d: 0.6923, real_score: 0.8632, fake_score: 0.1279
# Saving 0188.png
# Epoch [189/1000], loss_g: 2.2216, loss_d: 0.7171, real_score: 0.8338, fake_score: 0.1536
# Saving 0189.png
# Epoch [190/1000], loss_g: 2.3421, loss_d: 0.7009, real_score: 0.8300, fake_score: 0.0937
# Saving 0190.png
# Epoch [191/1000], loss_g: 2.4628, loss_d: 0.7321, real_score: 0.7933, fake_score: 0.0757
# Saving 0191.png
# Epoch [192/1000], loss_g: 1.2924, loss_d: 0.8854, real_score: 0.6377, fake_score: 0.0503
# Saving 0192.png
# Epoch [193/1000], loss_g: 2.1923, loss_d: 0.7106, real_score: 0.8261, fake_score: 0.1477
# Saving 0193.png
# Epoch [194/1000], loss_g: 1.9729, loss_d: 0.7142, real_score: 0.8036, fake_score: 0.1007
# Saving 0194.png
# Epoch [195/1000], loss_g: 2.2039, loss_d: 0.7103, real_score: 0.8597, fake_score: 0.1510
# Saving 0195.png
# Epoch [196/1000], loss_g: 2.4681, loss_d: 0.7074, real_score: 0.8699, fake_score: 0.1584
# Saving 0196.png
# Epoch [197/1000], loss_g: 2.0167, loss_d: 0.6854, real_score: 0.8518, fake_score: 0.1185
# Saving 0197.png
# Epoch [198/1000], loss_g: 1.7936, loss_d: 0.7116, real_score: 0.8014, fake_score: 0.1107
# Saving 0198.png
# Epoch [199/1000], loss_g: 2.6347, loss_d: 0.7177, real_score: 0.9145, fake_score: 0.2005
# Saving 0199.png
# Epoch [200/1000], loss_g: 1.8106, loss_d: 0.7360, real_score: 0.7841, fake_score: 0.0593
# Saving 0200.png
# Epoch [201/1000], loss_g: 2.6967, loss_d: 0.7034, real_score: 0.9196, fake_score: 0.1861
# Saving 0201.png
# Epoch [202/1000], loss_g: 4.1336, loss_d: 1.0397, real_score: 0.9684, fake_score: 0.4361
# Saving 0202.png
# Epoch [203/1000], loss_g: 2.5312, loss_d: 0.7752, real_score: 0.8583, fake_score: 0.2173
# Saving 0203.png
# Epoch [204/1000], loss_g: 1.9309, loss_d: 0.7596, real_score: 0.7759, fake_score: 0.1508
# Saving 0204.png
# Epoch [205/1000], loss_g: 2.4708, loss_d: 0.7106, real_score: 0.8552, fake_score: 0.1573
# Saving 0205.png
# Epoch [206/1000], loss_g: 2.8277, loss_d: 0.7299, real_score: 0.9029, fake_score: 0.2095
# Saving 0206.png
# Epoch [207/1000], loss_g: 2.1586, loss_d: 0.6938, real_score: 0.8531, fake_score: 0.0967
# Saving 0207.png
# Epoch [208/1000], loss_g: 2.3466, loss_d: 0.6869, real_score: 0.8886, fake_score: 0.1469
# Saving 0208.png
# Epoch [209/1000], loss_g: 2.2230, loss_d: 0.6840, real_score: 0.8628, fake_score: 0.1185
# Saving 0209.png
# Epoch [210/1000], loss_g: 2.3611, loss_d: 0.6955, real_score: 0.8900, fake_score: 0.1519
# Saving 0210.png
# Epoch [211/1000], loss_g: 2.6174, loss_d: 0.6976, real_score: 0.8990, fake_score: 0.1626
# Saving 0211.png
# Epoch [212/1000], loss_g: 2.5927, loss_d: 0.6790, real_score: 0.8651, fake_score: 0.1097
# Saving 0212.png
# Epoch [213/1000], loss_g: 1.7902, loss_d: 0.6881, real_score: 0.8816, fake_score: 0.1390
# Saving 0213.png
# Epoch [214/1000], loss_g: 3.1315, loss_d: 0.7242, real_score: 0.9152, fake_score: 0.2031
# Saving 0214.png
# Epoch [215/1000], loss_g: 2.3067, loss_d: 0.6783, real_score: 0.8648, fake_score: 0.0877
# Saving 0215.png
# Epoch [216/1000], loss_g: 2.6050, loss_d: 0.6932, real_score: 0.8945, fake_score: 0.1591
# Saving 0216.png
# Epoch [217/1000], loss_g: 2.3711, loss_d: 0.6846, real_score: 0.8580, fake_score: 0.1283
# Saving 0217.png
# Epoch [218/1000], loss_g: 2.3427, loss_d: 0.6868, real_score: 0.8564, fake_score: 0.1053
# Saving 0218.png
# Epoch [219/1000], loss_g: 2.0555, loss_d: 0.6788, real_score: 0.8769, fake_score: 0.1057
# Saving 0219.png
# Epoch [220/1000], loss_g: 2.8848, loss_d: 0.6900, real_score: 0.9004, fake_score: 0.1500
# Saving 0220.png
# Epoch [221/1000], loss_g: 2.0146, loss_d: 0.6793, real_score: 0.8643, fake_score: 0.1220
# Saving 0221.png
# Epoch [222/1000], loss_g: 1.8593, loss_d: 0.6887, real_score: 0.8410, fake_score: 0.1005
# Saving 0222.png
# Epoch [223/1000], loss_g: 2.5561, loss_d: 0.6850, real_score: 0.8923, fake_score: 0.1512
# Saving 0223.png
# Epoch [224/1000], loss_g: 3.3962, loss_d: 0.8174, real_score: 0.9480, fake_score: 0.2885
# Saving 0224.png
# Epoch [225/1000], loss_g: 2.6271, loss_d: 0.6960, real_score: 0.8682, fake_score: 0.1557
# Saving 0225.png
# Epoch [226/1000], loss_g: 2.4441, loss_d: 0.6824, real_score: 0.9088, fake_score: 0.1270
# Saving 0226.png
# Epoch [227/1000], loss_g: 5.0158, loss_d: 0.9471, real_score: 0.9659, fake_score: 0.3897
# Saving 0227.png
# Epoch [228/1000], loss_g: 2.4419, loss_d: 1.2667, real_score: 0.7280, fake_score: 0.4989
# Saving 0228.png
# Epoch [229/1000], loss_g: 2.1591, loss_d: 0.8614, real_score: 0.7789, fake_score: 0.2625
# Saving 0229.png
# Epoch [230/1000], loss_g: 2.3713, loss_d: 0.7733, real_score: 0.8204, fake_score: 0.1974
# Saving 0230.png
# Epoch [231/1000], loss_g: 2.3127, loss_d: 0.7427, real_score: 0.8168, fake_score: 0.1341
# Saving 0231.png
# Epoch [232/1000], loss_g: 2.0780, loss_d: 0.7238, real_score: 0.8268, fake_score: 0.1503
# Saving 0232.png
# Epoch [233/1000], loss_g: 2.4529, loss_d: 0.7026, real_score: 0.8899, fake_score: 0.1583
# Saving 0233.png
# Epoch [234/1000], loss_g: 1.9648, loss_d: 0.7102, real_score: 0.8417, fake_score: 0.1361
# Saving 0234.png
# Epoch [235/1000], loss_g: 2.5069, loss_d: 0.7136, real_score: 0.8446, fake_score: 0.1617
# Saving 0235.png
# Epoch [236/1000], loss_g: 2.5886, loss_d: 0.7029, real_score: 0.9023, fake_score: 0.1847
# Saving 0236.png
# Epoch [237/1000], loss_g: 1.7110, loss_d: 0.7106, real_score: 0.7964, fake_score: 0.0862
# Saving 0237.png
# Epoch [238/1000], loss_g: 2.4089, loss_d: 0.6741, real_score: 0.8907, fake_score: 0.1011
# Saving 0238.png
# Epoch [239/1000], loss_g: 1.8620, loss_d: 0.6873, real_score: 0.8459, fake_score: 0.1240
# Saving 0239.png
# Epoch [240/1000], loss_g: 2.4071, loss_d: 0.6757, real_score: 0.8742, fake_score: 0.1264
# Saving 0240.png
# Epoch [241/1000], loss_g: 2.0125, loss_d: 0.6728, real_score: 0.8686, fake_score: 0.1062
# Saving 0241.png
# Epoch [242/1000], loss_g: 2.1650, loss_d: 0.6854, real_score: 0.8476, fake_score: 0.1142
# Saving 0242.png
# Epoch [243/1000], loss_g: 2.0220, loss_d: 0.6857, real_score: 0.8529, fake_score: 0.1056
# Saving 0243.png
# Epoch [244/1000], loss_g: 2.2521, loss_d: 0.6809, real_score: 0.8624, fake_score: 0.0890
# Saving 0244.png
# Epoch [245/1000], loss_g: 2.2650, loss_d: 0.6764, real_score: 0.8956, fake_score: 0.1264
# Saving 0245.png
# Epoch [246/1000], loss_g: 2.0932, loss_d: 0.6723, real_score: 0.8856, fake_score: 0.1214
# Saving 0246.png
# Epoch [247/1000], loss_g: 2.1977, loss_d: 0.6765, real_score: 0.8608, fake_score: 0.1036
# Saving 0247.png
# Epoch [248/1000], loss_g: 1.9732, loss_d: 0.6793, real_score: 0.8540, fake_score: 0.0823
# Saving 0248.png
# Epoch [249/1000], loss_g: 2.7812, loss_d: 0.7033, real_score: 0.9361, fake_score: 0.1724
# Saving 0249.png
# Epoch [250/1000], loss_g: 2.1853, loss_d: 0.6810, real_score: 0.8497, fake_score: 0.0972
# Saving 0250.png
# Epoch [251/1000], loss_g: 3.2003, loss_d: 0.6987, real_score: 0.9185, fake_score: 0.1707
# Saving 0251.png
# Epoch [252/1000], loss_g: 2.9030, loss_d: 0.7065, real_score: 0.9294, fake_score: 0.1831
# Saving 0252.png
# Epoch [253/1000], loss_g: 2.0985, loss_d: 0.6820, real_score: 0.8546, fake_score: 0.0925
# Saving 0253.png
# Epoch [254/1000], loss_g: 2.5449, loss_d: 0.6918, real_score: 0.9254, fake_score: 0.1642
# Saving 0254.png
# Epoch [255/1000], loss_g: 2.2595, loss_d: 0.6782, real_score: 0.8757, fake_score: 0.1153
# Saving 0255.png
# Epoch [256/1000], loss_g: 2.5655, loss_d: 0.6848, real_score: 0.8630, fake_score: 0.1104
# Saving 0256.png
# Epoch [257/1000], loss_g: 2.2698, loss_d: 0.6674, real_score: 0.8947, fake_score: 0.1118
# Saving 0257.png
# Epoch [258/1000], loss_g: 2.1615, loss_d: 0.6749, real_score: 0.8826, fake_score: 0.1109
# Saving 0258.png
# Epoch [259/1000], loss_g: 2.0468, loss_d: 0.6815, real_score: 0.8416, fake_score: 0.0954
# Saving 0259.png
# Epoch [260/1000], loss_g: 2.2934, loss_d: 0.6757, real_score: 0.8964, fake_score: 0.1270
# Saving 0260.png
# Epoch [261/1000], loss_g: 2.6152, loss_d: 0.6723, real_score: 0.8984, fake_score: 0.1297
# Saving 0261.png
# Epoch [262/1000], loss_g: 3.1758, loss_d: 0.7200, real_score: 0.9392, fake_score: 0.2060
# Saving 0262.png
# Epoch [263/1000], loss_g: 2.4058, loss_d: 0.6734, real_score: 0.8850, fake_score: 0.1346
# Saving 0263.png
# Epoch [264/1000], loss_g: 2.2529, loss_d: 0.6736, real_score: 0.8641, fake_score: 0.1068
# Saving 0264.png
# Epoch [265/1000], loss_g: 1.9880, loss_d: 0.6867, real_score: 0.8435, fake_score: 0.0814
# Saving 0265.png
# Epoch [266/1000], loss_g: 2.4934, loss_d: 0.6719, real_score: 0.9091, fake_score: 0.1199
# Saving 0266.png
# Epoch [267/1000], loss_g: 2.0699, loss_d: 0.6815, real_score: 0.8381, fake_score: 0.0889
# Saving 0267.png
# Epoch [268/1000], loss_g: 2.6037, loss_d: 0.7175, real_score: 0.9387, fake_score: 0.1918
# Saving 0268.png
# Epoch [269/1000], loss_g: 2.2070, loss_d: 0.6742, real_score: 0.8632, fake_score: 0.0995
# Saving 0269.png
# Epoch [270/1000], loss_g: 2.5438, loss_d: 0.6870, real_score: 0.9095, fake_score: 0.1569
# Saving 0270.png
# Epoch [271/1000], loss_g: 1.9293, loss_d: 0.7313, real_score: 0.7810, fake_score: 0.0585
# Saving 0271.png
# Epoch [272/1000], loss_g: 1.9966, loss_d: 0.6818, real_score: 0.8517, fake_score: 0.1104
# Saving 0272.png
# Epoch [273/1000], loss_g: 2.2071, loss_d: 0.6829, real_score: 0.8519, fake_score: 0.0819
# Saving 0273.png
# Epoch [274/1000], loss_g: 2.7350, loss_d: 0.6696, real_score: 0.8931, fake_score: 0.1068
# Saving 0274.png
# Epoch [275/1000], loss_g: 2.5921, loss_d: 0.6989, real_score: 0.9200, fake_score: 0.1822
# Saving 0275.png
# Epoch [276/1000], loss_g: 2.2229, loss_d: 0.6690, real_score: 0.8831, fake_score: 0.1198
# Saving 0276.png
# Epoch [277/1000], loss_g: 2.0439, loss_d: 0.6717, real_score: 0.8630, fake_score: 0.0947
# Saving 0277.png
# Epoch [278/1000], loss_g: 1.4665, loss_d: 0.7815, real_score: 0.7353, fake_score: 0.0459
# Saving 0278.png
# Epoch [279/1000], loss_g: 2.3399, loss_d: 0.6764, real_score: 0.8680, fake_score: 0.1186
# Saving 0279.png
# Epoch [280/1000], loss_g: 2.2961, loss_d: 0.6810, real_score: 0.8926, fake_score: 0.1327
# Saving 0280.png
# Epoch [281/1000], loss_g: 2.4906, loss_d: 0.6780, real_score: 0.8712, fake_score: 0.1254
# Saving 0281.png
# Epoch [282/1000], loss_g: 2.8655, loss_d: 0.6839, real_score: 0.9009, fake_score: 0.1549
# Saving 0282.png
# Epoch [283/1000], loss_g: 2.1196, loss_d: 0.6879, real_score: 0.8374, fake_score: 0.0764
# Saving 0283.png
# Epoch [284/1000], loss_g: 2.1332, loss_d: 0.6903, real_score: 0.8371, fake_score: 0.0808
# Saving 0284.png
# Epoch [285/1000], loss_g: 1.3863, loss_d: 0.7377, real_score: 0.7660, fake_score: 0.0648
# Saving 0285.png
# Epoch [286/1000], loss_g: 2.4676, loss_d: 0.6862, real_score: 0.8658, fake_score: 0.1229
# Saving 0286.png
# Epoch [287/1000], loss_g: 2.5258, loss_d: 0.6881, real_score: 0.8712, fake_score: 0.1371
# Saving 0287.png
# Epoch [288/1000], loss_g: 2.3981, loss_d: 0.6785, real_score: 0.8825, fake_score: 0.1143
# Saving 0288.png
# Epoch [289/1000], loss_g: 2.7884, loss_d: 0.6753, real_score: 0.9093, fake_score: 0.1313
# Saving 0289.png
# Epoch [290/1000], loss_g: 2.3668, loss_d: 0.6897, real_score: 0.9357, fake_score: 0.1439
# Saving 0290.png
# Epoch [291/1000], loss_g: 2.8595, loss_d: 0.7033, real_score: 0.9338, fake_score: 0.1737
# Saving 0291.png
# Epoch [292/1000], loss_g: 2.0410, loss_d: 0.6886, real_score: 0.8379, fake_score: 0.0686
# Saving 0292.png
# Epoch [293/1000], loss_g: 2.3098, loss_d: 0.6820, real_score: 0.8528, fake_score: 0.1092
# Saving 0293.png
# Epoch [294/1000], loss_g: 2.0924, loss_d: 0.6706, real_score: 0.8800, fake_score: 0.1103
# Saving 0294.png
# Epoch [295/1000], loss_g: 1.9918, loss_d: 0.6884, real_score: 0.8553, fake_score: 0.0678
# Saving 0295.png
# Epoch [296/1000], loss_g: 2.8500, loss_d: 0.6788, real_score: 0.9216, fake_score: 0.1475
# Saving 0296.png
# Epoch [297/1000], loss_g: 2.3042, loss_d: 0.6671, real_score: 0.8820, fake_score: 0.0896
# Saving 0297.png
# Epoch [298/1000], loss_g: 3.4921, loss_d: 0.7886, real_score: 0.9510, fake_score: 0.2672
# Saving 0298.png
# Epoch [299/1000], loss_g: 2.3099, loss_d: 0.6758, real_score: 0.8875, fake_score: 0.1167
# Saving 0299.png
# Epoch [300/1000], loss_g: 2.5952, loss_d: 0.6775, real_score: 0.9048, fake_score: 0.1508
# Saving 0300.png
# Epoch [301/1000], loss_g: 1.8862, loss_d: 0.6805, real_score: 0.8551, fake_score: 0.0723
# Saving 0301.png
# Epoch [302/1000], loss_g: 2.1335, loss_d: 0.6673, real_score: 0.8804, fake_score: 0.1161
# Saving 0302.png
# Epoch [303/1000], loss_g: 2.0197, loss_d: 0.6769, real_score: 0.8510, fake_score: 0.0925
# Saving 0303.png
# Epoch [304/1000], loss_g: 2.5138, loss_d: 0.6673, real_score: 0.8937, fake_score: 0.1289
# Saving 0304.png
# Epoch [305/1000], loss_g: 2.7559, loss_d: 0.6828, real_score: 0.9219, fake_score: 0.1533
# Saving 0305.png
# Epoch [306/1000], loss_g: 2.2442, loss_d: 0.6684, real_score: 0.8820, fake_score: 0.1071
# Saving 0306.png
# Epoch [307/1000], loss_g: 2.4549, loss_d: 0.6720, real_score: 0.8790, fake_score: 0.1226
# Saving 0307.png
# Epoch [308/1000], loss_g: 2.4075, loss_d: 0.6691, real_score: 0.8702, fake_score: 0.1019
# Saving 0308.png
# Epoch [309/1000], loss_g: 1.7277, loss_d: 0.6942, real_score: 0.8275, fake_score: 0.0880
# Saving 0309.png
# Epoch [310/1000], loss_g: 1.1151, loss_d: 1.2938, real_score: 0.4695, fake_score: 0.2686
# Saving 0310.png
# Epoch [311/1000], loss_g: 1.7712, loss_d: 1.1433, real_score: 0.5387, fake_score: 0.1173
# Saving 0311.png
# Epoch [312/1000], loss_g: 1.4297, loss_d: 1.0993, real_score: 0.6744, fake_score: 0.4023
# Saving 0312.png
# Epoch [313/1000], loss_g: 3.5513, loss_d: 0.9513, real_score: 0.8339, fake_score: 0.3699
# Saving 0313.png
# Epoch [314/1000], loss_g: 1.5260, loss_d: 0.8920, real_score: 0.6818, fake_score: 0.1873
# Saving 0314.png
# Epoch [315/1000], loss_g: 2.3570, loss_d: 0.8414, real_score: 0.7420, fake_score: 0.1718
# Saving 0315.png
# Epoch [316/1000], loss_g: 3.3669, loss_d: 0.8185, real_score: 0.8640, fake_score: 0.2771
# Saving 0316.png
# Epoch [317/1000], loss_g: 2.1084, loss_d: 0.7758, real_score: 0.7786, fake_score: 0.1733
# Saving 0317.png
# Epoch [318/1000], loss_g: 2.2147, loss_d: 0.7597, real_score: 0.7888, fake_score: 0.1135
# Saving 0318.png
# Epoch [319/1000], loss_g: 2.6254, loss_d: 0.7206, real_score: 0.8308, fake_score: 0.1339
# Saving 0319.png
# Epoch [320/1000], loss_g: 2.9098, loss_d: 0.7061, real_score: 0.8786, fake_score: 0.1581
# Saving 0320.png
# Epoch [321/1000], loss_g: 2.6881, loss_d: 0.6934, real_score: 0.8639, fake_score: 0.1263
# Saving 0321.png
# Epoch [322/1000], loss_g: 2.2696, loss_d: 0.6832, real_score: 0.8744, fake_score: 0.1232
# Saving 0322.png
# Epoch [323/1000], loss_g: 2.1606, loss_d: 0.6948, real_score: 0.8445, fake_score: 0.1112
# Saving 0323.png
# Epoch [324/1000], loss_g: 2.2188, loss_d: 0.6875, real_score: 0.8655, fake_score: 0.1296
# Saving 0324.png
# Epoch [325/1000], loss_g: 2.0113, loss_d: 0.6791, real_score: 0.8615, fake_score: 0.1153
# Saving 0325.png
# Epoch [326/1000], loss_g: 2.2189, loss_d: 0.6832, real_score: 0.8454, fake_score: 0.0986
# Saving 0326.png
# Epoch [327/1000], loss_g: 2.3518, loss_d: 0.6877, real_score: 0.8394, fake_score: 0.0958
# Saving 0327.png
# Epoch [328/1000], loss_g: 2.5517, loss_d: 0.6702, real_score: 0.8993, fake_score: 0.1201
# Saving 0328.png
# Epoch [329/1000], loss_g: 2.2637, loss_d: 0.6776, real_score: 0.8619, fake_score: 0.0936
# Saving 0329.png
# Epoch [330/1000], loss_g: 2.5026, loss_d: 0.6717, real_score: 0.8846, fake_score: 0.1390
# Saving 0330.png
# Epoch [331/1000], loss_g: 2.1278, loss_d: 0.6734, real_score: 0.8672, fake_score: 0.1152
# Saving 0331.png
# Epoch [332/1000], loss_g: 2.4805, loss_d: 0.6939, real_score: 0.8943, fake_score: 0.1624
# Saving 0332.png
# Epoch [333/1000], loss_g: 2.2784, loss_d: 0.6772, real_score: 0.8713, fake_score: 0.1272
# Saving 0333.png
# Epoch [334/1000], loss_g: 2.1919, loss_d: 0.6782, real_score: 0.8855, fake_score: 0.1304
# Saving 0334.png
# Epoch [335/1000], loss_g: 2.0793, loss_d: 0.6798, real_score: 0.8607, fake_score: 0.0914
# Saving 0335.png
# Epoch [336/1000], loss_g: 2.1101, loss_d: 0.6785, real_score: 0.8648, fake_score: 0.1181
# Saving 0336.png
# Epoch [337/1000], loss_g: 1.9819, loss_d: 0.6735, real_score: 0.8760, fake_score: 0.1190
# Saving 0337.png
# Epoch [338/1000], loss_g: 2.3353, loss_d: 0.6653, real_score: 0.8860, fake_score: 0.1224
# Saving 0338.png
# Epoch [339/1000], loss_g: 2.4565, loss_d: 0.6901, real_score: 0.9163, fake_score: 0.1477
# Saving 0339.png
# Epoch [340/1000], loss_g: 2.5625, loss_d: 0.6794, real_score: 0.8978, fake_score: 0.1584
# Saving 0340.png
# Epoch [341/1000], loss_g: 2.5752, loss_d: 0.6988, real_score: 0.9280, fake_score: 0.1781
# Saving 0341.png
# Epoch [342/1000], loss_g: 2.6033, loss_d: 0.6747, real_score: 0.9157, fake_score: 0.1276
# Saving 0342.png
# Epoch [343/1000], loss_g: 2.4116, loss_d: 0.6706, real_score: 0.8825, fake_score: 0.0875
# Saving 0343.png
# Epoch [344/1000], loss_g: 2.5177, loss_d: 0.6710, real_score: 0.8940, fake_score: 0.1355
# Saving 0344.png
# Epoch [345/1000], loss_g: 2.3322, loss_d: 0.6666, real_score: 0.8979, fake_score: 0.1171
# Saving 0345.png
# Epoch [346/1000], loss_g: 2.9314, loss_d: 0.6797, real_score: 0.9118, fake_score: 0.1476
# Saving 0346.png
# Epoch [347/1000], loss_g: 2.8965, loss_d: 0.6741, real_score: 0.9107, fake_score: 0.1425
# Saving 0347.png
# Epoch [348/1000], loss_g: 2.0628, loss_d: 0.6727, real_score: 0.8633, fake_score: 0.0799
# Saving 0348.png
# Epoch [349/1000], loss_g: 2.0650, loss_d: 0.6709, real_score: 0.8809, fake_score: 0.1069
# Saving 0349.png
# Epoch [350/1000], loss_g: 2.1423, loss_d: 0.6932, real_score: 0.8304, fake_score: 0.0668
# Saving 0350.png
# Epoch [351/1000], loss_g: 2.3620, loss_d: 0.6697, real_score: 0.8813, fake_score: 0.1103
# Saving 0351.png
# Epoch [352/1000], loss_g: 3.1571, loss_d: 0.6924, real_score: 0.9128, fake_score: 0.1715
# Saving 0352.png
# Epoch [353/1000], loss_g: 2.4110, loss_d: 0.6730, real_score: 0.8803, fake_score: 0.1111
# Saving 0353.png
# Epoch [354/1000], loss_g: 2.4223, loss_d: 0.6668, real_score: 0.9123, fake_score: 0.1234
# Saving 0354.png
# Epoch [355/1000], loss_g: 2.0483, loss_d: 0.6653, real_score: 0.9008, fake_score: 0.1040
# Saving 0355.png
# Epoch [356/1000], loss_g: 2.6047, loss_d: 0.6837, real_score: 0.9291, fake_score: 0.1551
# Saving 0356.png
# Epoch [357/1000], loss_g: 2.1910, loss_d: 0.6707, real_score: 0.8570, fake_score: 0.0860
# Saving 0357.png
# Epoch [358/1000], loss_g: 1.9760, loss_d: 0.6664, real_score: 0.8770, fake_score: 0.0920
# Saving 0358.png
# Epoch [359/1000], loss_g: 2.4198, loss_d: 0.6730, real_score: 0.9044, fake_score: 0.1386
# Saving 0359.png
# Epoch [360/1000], loss_g: 2.1231, loss_d: 0.6780, real_score: 0.8461, fake_score: 0.0847
# Saving 0360.png
# Epoch [361/1000], loss_g: 2.2572, loss_d: 0.6637, real_score: 0.8864, fake_score: 0.1015
# Saving 0361.png
# Epoch [362/1000], loss_g: 1.9037, loss_d: 0.6781, real_score: 0.8406, fake_score: 0.0840
# Saving 0362.png
# Epoch [363/1000], loss_g: 2.5542, loss_d: 0.6639, real_score: 0.8841, fake_score: 0.0945
# Saving 0363.png
# Epoch [364/1000], loss_g: 2.1818, loss_d: 0.6653, real_score: 0.8811, fake_score: 0.0996
# Saving 0364.png
# Epoch [365/1000], loss_g: 1.5928, loss_d: 0.7170, real_score: 0.7975, fake_score: 0.0601
# Saving 0365.png
# Epoch [366/1000], loss_g: 2.5917, loss_d: 0.6705, real_score: 0.9065, fake_score: 0.1145
# Saving 0366.png
# Epoch [367/1000], loss_g: 2.6481, loss_d: 0.6743, real_score: 0.9113, fake_score: 0.1405
# Saving 0367.png
# Epoch [368/1000], loss_g: 2.8482, loss_d: 0.6956, real_score: 0.9156, fake_score: 0.1817
# Saving 0368.png
# Epoch [369/1000], loss_g: 2.7192, loss_d: 0.6785, real_score: 0.9238, fake_score: 0.1511
# Saving 0369.png
# Epoch [370/1000], loss_g: 2.3057, loss_d: 0.6665, real_score: 0.9054, fake_score: 0.1114
# Saving 0370.png
# Epoch [371/1000], loss_g: 2.0851, loss_d: 0.6837, real_score: 0.8407, fake_score: 0.0775
# Saving 0371.png
# Epoch [372/1000], loss_g: 2.5739, loss_d: 0.6650, real_score: 0.9012, fake_score: 0.1249
# Saving 0372.png
# Epoch [373/1000], loss_g: 1.8824, loss_d: 0.6793, real_score: 0.8457, fake_score: 0.0962
# Saving 0373.png
# Epoch [374/1000], loss_g: 2.5114, loss_d: 0.6746, real_score: 0.9061, fake_score: 0.1460
# Saving 0374.png
# Epoch [375/1000], loss_g: 2.4452, loss_d: 0.6665, real_score: 0.8967, fake_score: 0.1055
# Saving 0375.png
# Epoch [376/1000], loss_g: 2.2038, loss_d: 0.6613, real_score: 0.8851, fake_score: 0.1045
# Saving 0376.png
# Epoch [377/1000], loss_g: 2.4285, loss_d: 0.6674, real_score: 0.8749, fake_score: 0.1015
# Saving 0377.png
# Epoch [378/1000], loss_g: 2.2147, loss_d: 0.6657, real_score: 0.8833, fake_score: 0.0966
# Saving 0378.png
# Epoch [379/1000], loss_g: 2.5963, loss_d: 0.6710, real_score: 0.9191, fake_score: 0.1308
# Saving 0379.png
# Epoch [380/1000], loss_g: 2.8384, loss_d: 0.6831, real_score: 0.9330, fake_score: 0.1515
# Saving 0380.png
# Epoch [381/1000], loss_g: 2.1003, loss_d: 0.6774, real_score: 0.8581, fake_score: 0.0801
# Saving 0381.png
# Epoch [382/1000], loss_g: 2.0058, loss_d: 0.6675, real_score: 0.8688, fake_score: 0.0908
# Saving 0382.png
# Epoch [383/1000], loss_g: 2.4428, loss_d: 0.6685, real_score: 0.8784, fake_score: 0.1038
# Saving 0383.png
# Epoch [384/1000], loss_g: 2.2500, loss_d: 0.6700, real_score: 0.8619, fake_score: 0.0938
# Saving 0384.png
# Epoch [385/1000], loss_g: 2.5049, loss_d: 0.6631, real_score: 0.8814, fake_score: 0.1057
# Saving 0385.png
# Epoch [386/1000], loss_g: 1.6767, loss_d: 0.7778, real_score: 0.7350, fake_score: 0.0469
# Saving 0386.png
# Epoch [387/1000], loss_g: 2.1239, loss_d: 0.6704, real_score: 0.8849, fake_score: 0.0895
# Saving 0387.png
# Epoch [388/1000], loss_g: 2.3482, loss_d: 0.6708, real_score: 0.9165, fake_score: 0.1240
# Saving 0388.png
# Epoch [389/1000], loss_g: 2.2364, loss_d: 0.6721, real_score: 0.8587, fake_score: 0.0898
# Saving 0389.png
# Epoch [390/1000], loss_g: 2.8405, loss_d: 0.6857, real_score: 0.9287, fake_score: 0.1585
# Saving 0390.png
# Epoch [391/1000], loss_g: 2.6777, loss_d: 0.6833, real_score: 0.9235, fake_score: 0.1598
# Saving 0391.png
# Epoch [392/1000], loss_g: 3.5010, loss_d: 0.7349, real_score: 0.9456, fake_score: 0.2217
# Saving 0392.png
# Epoch [393/1000], loss_g: 2.5996, loss_d: 0.6755, real_score: 0.9167, fake_score: 0.1361
# Saving 0393.png
# Epoch [394/1000], loss_g: 2.2093, loss_d: 0.6740, real_score: 0.8664, fake_score: 0.0882
# Saving 0394.png
# Epoch [395/1000], loss_g: 2.7303, loss_d: 0.6650, real_score: 0.9125, fake_score: 0.1191
# Saving 0395.png
# Epoch [396/1000], loss_g: 2.1429, loss_d: 0.6735, real_score: 0.8586, fake_score: 0.0795
# Saving 0396.png
# Epoch [397/1000], loss_g: 2.6254, loss_d: 0.6709, real_score: 0.9095, fake_score: 0.1381
# Saving 0397.png
# Epoch [398/1000], loss_g: 2.3335, loss_d: 0.6668, real_score: 0.8816, fake_score: 0.0829
# Saving 0398.png
# Epoch [399/1000], loss_g: 2.1864, loss_d: 0.6674, real_score: 0.8732, fake_score: 0.1070
# Saving 0399.png
# Epoch [400/1000], loss_g: 2.7531, loss_d: 0.6721, real_score: 0.9039, fake_score: 0.1314
# Saving 0400.png
# Epoch [401/1000], loss_g: 2.4589, loss_d: 0.6706, real_score: 0.9228, fake_score: 0.1204
# Saving 0401.png
# Epoch [402/1000], loss_g: 2.3794, loss_d: 0.6824, real_score: 0.8585, fake_score: 0.0684
# Saving 0402.png
# Epoch [403/1000], loss_g: 2.4062, loss_d: 0.6669, real_score: 0.9085, fake_score: 0.1200
# Saving 0403.png
# Epoch [404/1000], loss_g: 1.6712, loss_d: 0.7526, real_score: 0.7590, fake_score: 0.0551
# Saving 0404.png
# Epoch [405/1000], loss_g: 0.5520, loss_d: 1.5379, real_score: 0.4146, fake_score: 0.2896
# Saving 0405.png
# Epoch [406/1000], loss_g: 3.3963, loss_d: 1.6293, real_score: 0.8948, fake_score: 0.7066
# Saving 0406.png
# Epoch [407/1000], loss_g: 1.9990, loss_d: 1.3918, real_score: 0.8312, fake_score: 0.5778
# Saving 0407.png
# Epoch [408/1000], loss_g: 3.2759, loss_d: 1.3222, real_score: 0.9015, fake_score: 0.5642
# Saving 0408.png
# Epoch [409/1000], loss_g: 2.3876, loss_d: 1.3836, real_score: 0.4331, fake_score: 0.0365
# Saving 0409.png
# Epoch [410/1000], loss_g: 2.5233, loss_d: 0.8751, real_score: 0.7814, fake_score: 0.2544
# Saving 0410.png
# Epoch [411/1000], loss_g: 3.1481, loss_d: 0.7892, real_score: 0.8747, fake_score: 0.2347
# Saving 0411.png
# Epoch [412/1000], loss_g: 2.5123, loss_d: 0.7611, real_score: 0.7876, fake_score: 0.1314
# Saving 0412.png
# Epoch [413/1000], loss_g: 2.3576, loss_d: 0.7336, real_score: 0.8493, fake_score: 0.1659
# Saving 0413.png
# Epoch [414/1000], loss_g: 1.8512, loss_d: 0.7371, real_score: 0.7928, fake_score: 0.1176
# Saving 0414.png
# Epoch [415/1000], loss_g: 2.6384, loss_d: 0.6982, real_score: 0.8885, fake_score: 0.1510
# Saving 0415.png
# Epoch [416/1000], loss_g: 2.3863, loss_d: 0.6967, real_score: 0.8574, fake_score: 0.1254
# Saving 0416.png
# Epoch [417/1000], loss_g: 2.7790, loss_d: 0.7074, real_score: 0.9151, fake_score: 0.1772
# Saving 0417.png
# Epoch [418/1000], loss_g: 2.2640, loss_d: 0.7002, real_score: 0.8744, fake_score: 0.1617
# Saving 0418.png
# Epoch [419/1000], loss_g: 3.0981, loss_d: 0.7449, real_score: 0.9264, fake_score: 0.2322
# Saving 0419.png
# Epoch [420/1000], loss_g: 2.5450, loss_d: 0.6789, real_score: 0.9056, fake_score: 0.1480
# Saving 0420.png
# Epoch [421/1000], loss_g: 2.7152, loss_d: 0.6998, real_score: 0.9307, fake_score: 0.1726
# Saving 0421.png
# Epoch [422/1000], loss_g: 2.8691, loss_d: 0.6938, real_score: 0.8990, fake_score: 0.1530
# Saving 0422.png
# Epoch [423/1000], loss_g: 2.4671, loss_d: 0.6768, real_score: 0.8764, fake_score: 0.1218
# Saving 0423.png
# Epoch [424/1000], loss_g: 2.2768, loss_d: 0.6734, real_score: 0.8659, fake_score: 0.1093
# Saving 0424.png
# Epoch [425/1000], loss_g: 2.2359, loss_d: 0.6738, real_score: 0.8744, fake_score: 0.1077
# Saving 0425.png
# Epoch [426/1000], loss_g: 2.1565, loss_d: 0.6873, real_score: 0.8384, fake_score: 0.0852
# Saving 0426.png
# Epoch [427/1000], loss_g: 1.9086, loss_d: 0.6998, real_score: 0.8233, fake_score: 0.0807
# Saving 0427.png
# Epoch [428/1000], loss_g: 2.7046, loss_d: 0.6891, real_score: 0.9072, fake_score: 0.1637
# Saving 0428.png
# Epoch [429/1000], loss_g: 2.5877, loss_d: 0.6664, real_score: 0.8951, fake_score: 0.1233
# Saving 0429.png
# Epoch [430/1000], loss_g: 2.6627, loss_d: 0.6804, real_score: 0.9097, fake_score: 0.1577
# Saving 0430.png
# Epoch [431/1000], loss_g: 2.1466, loss_d: 0.6676, real_score: 0.8674, fake_score: 0.0918
# Saving 0431.png
# Epoch [432/1000], loss_g: 2.2567, loss_d: 0.6763, real_score: 0.8549, fake_score: 0.0870
# Saving 0432.png
# Epoch [433/1000], loss_g: 2.2757, loss_d: 0.6816, real_score: 0.8504, fake_score: 0.0794
# Saving 0433.png
# Epoch [434/1000], loss_g: 2.5898, loss_d: 0.6768, real_score: 0.9130, fake_score: 0.1501
# Saving 0434.png
# Epoch [435/1000], loss_g: 2.5697, loss_d: 0.6662, real_score: 0.8883, fake_score: 0.1216
# Saving 0435.png
# Epoch [436/1000], loss_g: 2.3491, loss_d: 0.6736, real_score: 0.8700, fake_score: 0.0846
# Saving 0436.png
# Epoch [437/1000], loss_g: 2.4732, loss_d: 0.6684, real_score: 0.9131, fake_score: 0.1330
# Saving 0437.png
# Epoch [438/1000], loss_g: 2.1467, loss_d: 0.6710, real_score: 0.8617, fake_score: 0.1009
# Saving 0438.png
# Epoch [439/1000], loss_g: 2.3130, loss_d: 0.6683, real_score: 0.8889, fake_score: 0.1181
# Saving 0439.png
# Epoch [440/1000], loss_g: 2.5313, loss_d: 0.6707, real_score: 0.8967, fake_score: 0.1413
# Saving 0440.png
# Epoch [441/1000], loss_g: 2.0358, loss_d: 0.6724, real_score: 0.8484, fake_score: 0.0965
# Saving 0441.png
# Epoch [442/1000], loss_g: 2.1737, loss_d: 0.6647, real_score: 0.8842, fake_score: 0.1008
# Saving 0442.png
# Epoch [443/1000], loss_g: 2.0576, loss_d: 0.6648, real_score: 0.8921, fake_score: 0.1189
# Saving 0443.png
# Epoch [444/1000], loss_g: 2.7037, loss_d: 0.6696, real_score: 0.9131, fake_score: 0.1320
# Saving 0444.png
# Epoch [445/1000], loss_g: 2.1670, loss_d: 0.6700, real_score: 0.8785, fake_score: 0.1137
# Saving 0445.png
# Epoch [446/1000], loss_g: 2.2234, loss_d: 0.6683, real_score: 0.8637, fake_score: 0.1005
# Saving 0446.png
# Epoch [447/1000], loss_g: 2.4202, loss_d: 0.6642, real_score: 0.8824, fake_score: 0.0971
# Saving 0447.png
# Epoch [448/1000], loss_g: 2.1425, loss_d: 0.6672, real_score: 0.8977, fake_score: 0.0917
# Saving 0448.png
# Epoch [449/1000], loss_g: 2.3830, loss_d: 0.6716, real_score: 0.8974, fake_score: 0.1349
# Saving 0449.png
# Epoch [450/1000], loss_g: 2.3118, loss_d: 0.6611, real_score: 0.8983, fake_score: 0.1089
# Saving 0450.png
# Epoch [451/1000], loss_g: 2.4638, loss_d: 0.6668, real_score: 0.9148, fake_score: 0.1301
# Saving 0451.png
# Epoch [452/1000], loss_g: 2.2922, loss_d: 0.6828, real_score: 0.8493, fake_score: 0.0733
# Saving 0452.png
# Epoch [453/1000], loss_g: 2.3903, loss_d: 0.6679, real_score: 0.8785, fake_score: 0.0832
# Saving 0453.png
# Epoch [454/1000], loss_g: 2.2627, loss_d: 0.6654, real_score: 0.8737, fake_score: 0.0997
# Saving 0454.png
# Epoch [455/1000], loss_g: 2.4153, loss_d: 0.6669, real_score: 0.9019, fake_score: 0.1275
# Saving 0455.png
# Epoch [456/1000], loss_g: 2.6382, loss_d: 0.6638, real_score: 0.8949, fake_score: 0.1193
# Saving 0456.png
# Epoch [457/1000], loss_g: 3.2486, loss_d: 0.7180, real_score: 0.9494, fake_score: 0.1959
# Saving 0457.png
# Epoch [458/1000], loss_g: 2.6110, loss_d: 0.6762, real_score: 0.9203, fake_score: 0.1442
# Saving 0458.png
# ...
# Saving 0848.png
# Epoch [849/1000], loss_g: 2.4526, loss_d: 0.6702, real_score: 0.8820, fake_score: 0.1118
# Saving 0849.png
# Epoch [850/1000], loss_g: 2.3877, loss_d: 0.6637, real_score: 0.8825, fake_score: 0.1120
# Saving 0850.png
# Epoch [851/1000], loss_g: 2.4219, loss_d: 0.6671, real_score: 0.8714, fake_score: 0.0868
# Saving 0851.png
# Epoch [852/1000], loss_g: 2.2898, loss_d: 0.6654, real_score: 0.8915, fake_score: 0.0968
# Saving 0852.png
# Epoch [853/1000], loss_g: 2.4492, loss_d: 0.6604, real_score: 0.8841, fake_score: 0.1037
# Saving 0853.png
# Epoch [854/1000], loss_g: 2.2224, loss_d: 0.6618, real_score: 0.8850, fake_score: 0.0941
# Saving 0854.png
# Epoch [855/1000], loss_g: 2.4995, loss_d: 0.6607, real_score: 0.9018, fake_score: 0.1188
# Saving 0855.png
# Epoch [856/1000], loss_g: 2.0880, loss_d: 0.6623, real_score: 0.8768, fake_score: 0.0952
# Saving 0856.png
# Epoch [857/1000], loss_g: 2.0768, loss_d: 0.6639, real_score: 0.8926, fake_score: 0.1103
# Saving 0857.png
# Epoch [858/1000], loss_g: 2.1425, loss_d: 0.6635, real_score: 0.8714, fake_score: 0.0991
# Saving 0858.png
# Epoch [859/1000], loss_g: 2.5016, loss_d: 0.6612, real_score: 0.8962, fake_score: 0.1158
# Saving 0859.png
# Epoch [860/1000], loss_g: 2.2835, loss_d: 0.6586, real_score: 0.8924, fake_score: 0.1042
# Saving 0860.png
# Epoch [861/1000], loss_g: 2.5847, loss_d: 0.6597, real_score: 0.9112, fake_score: 0.1153
# Saving 0861.png
# Epoch [862/1000], loss_g: 2.1899, loss_d: 0.6617, real_score: 0.8756, fake_score: 0.0958
# Saving 0862.png
# Epoch [863/1000], loss_g: 2.0397, loss_d: 0.6751, real_score: 0.8504, fake_score: 0.0701
# Saving 0863.png
# Epoch [864/1000], loss_g: 2.3761, loss_d: 0.6601, real_score: 0.9000, fake_score: 0.1231
# Saving 0864.png
# Epoch [865/1000], loss_g: 2.3842, loss_d: 0.6578, real_score: 0.8998, fake_score: 0.1045
# Saving 0865.png
# Epoch [866/1000], loss_g: 2.4047, loss_d: 0.6594, real_score: 0.8873, fake_score: 0.0934
# Saving 0866.png
# Epoch [867/1000], loss_g: 2.1262, loss_d: 0.6751, real_score: 0.8497, fake_score: 0.0693
# Saving 0867.png
# Epoch [868/1000], loss_g: 2.2819, loss_d: 0.6693, real_score: 0.8604, fake_score: 0.0814
# Saving 0868.png
# Epoch [869/1000], loss_g: 2.4742, loss_d: 0.6621, real_score: 0.9053, fake_score: 0.1246
# Saving 0869.png
# Epoch [870/1000], loss_g: 2.3947, loss_d: 0.6608, real_score: 0.9121, fake_score: 0.1030
# Saving 0870.png
# Epoch [871/1000], loss_g: 2.3859, loss_d: 0.6578, real_score: 0.9024, fake_score: 0.1168
# Saving 0871.png
# Epoch [872/1000], loss_g: 2.0839, loss_d: 0.6627, real_score: 0.8769, fake_score: 0.0968
# Saving 0872.png
# Epoch [873/1000], loss_g: 2.1728, loss_d: 0.6641, real_score: 0.8635, fake_score: 0.0820
# Saving 0873.png
# Epoch [874/1000], loss_g: 2.3337, loss_d: 0.6648, real_score: 0.8758, fake_score: 0.0800
# Saving 0874.png
# Epoch [875/1000], loss_g: 2.5128, loss_d: 0.6608, real_score: 0.8925, fake_score: 0.1205
# Saving 0875.png
# Epoch [876/1000], loss_g: 2.2931, loss_d: 0.6577, real_score: 0.9122, fake_score: 0.1148
# Saving 0876.png
# Epoch [877/1000], loss_g: 2.0860, loss_d: 0.6729, real_score: 0.8528, fake_score: 0.0714
# Saving 0877.png
# Epoch [878/1000], loss_g: 2.0031, loss_d: 0.6617, real_score: 0.8751, fake_score: 0.1049
# Saving 0878.png
# Epoch [879/1000], loss_g: 2.5968, loss_d: 0.6648, real_score: 0.9004, fake_score: 0.1344
# Saving 0879.png
# Epoch [880/1000], loss_g: 2.2930, loss_d: 0.6586, real_score: 0.8934, fake_score: 0.1063
# Saving 0880.png
# Epoch [881/1000], loss_g: 2.2106, loss_d: 0.6572, real_score: 0.8825, fake_score: 0.1004
# Saving 0881.png
# Epoch [882/1000], loss_g: 1.8539, loss_d: 0.6627, real_score: 0.8687, fake_score: 0.0861
# Saving 0882.png
# Epoch [883/1000], loss_g: 2.1814, loss_d: 0.6649, real_score: 0.8732, fake_score: 0.0819
# Saving 0883.png
# Epoch [884/1000], loss_g: 2.3036, loss_d: 0.6575, real_score: 0.9009, fake_score: 0.1101
# Saving 0884.png
# Epoch [885/1000], loss_g: 2.4704, loss_d: 0.6594, real_score: 0.8942, fake_score: 0.1175
# Saving 0885.png
# Epoch [886/1000], loss_g: 2.7129, loss_d: 0.6657, real_score: 0.9267, fake_score: 0.1298
# Saving 0886.png
# Epoch [887/1000], loss_g: 2.5538, loss_d: 0.6650, real_score: 0.9189, fake_score: 0.1230
# Saving 0887.png
# Epoch [888/1000], loss_g: 2.5292, loss_d: 0.6626, real_score: 0.9155, fake_score: 0.1297
# Saving 0888.png
# Epoch [889/1000], loss_g: 1.9232, loss_d: 0.6787, real_score: 0.8472, fake_score: 0.0654
# Saving 0889.png
# Epoch [890/1000], loss_g: 2.3603, loss_d: 0.6610, real_score: 0.8940, fake_score: 0.0941
# Saving 0890.png
# Epoch [891/1000], loss_g: 2.2401, loss_d: 0.6594, real_score: 0.8851, fake_score: 0.0960
# Saving 0891.png
# Epoch [892/1000], loss_g: 2.8778, loss_d: 0.6659, real_score: 0.9169, fake_score: 0.1360
# Saving 0892.png
# Epoch [893/1000], loss_g: 2.6875, loss_d: 0.6595, real_score: 0.9122, fake_score: 0.1184
# Saving 0893.png
# Epoch [894/1000], loss_g: 2.5772, loss_d: 0.6619, real_score: 0.9117, fake_score: 0.1310
# Saving 0894.png
# Epoch [895/1000], loss_g: 2.3261, loss_d: 0.6575, real_score: 0.9034, fake_score: 0.1088
# Saving 0895.png
# Epoch [896/1000], loss_g: 2.2420, loss_d: 0.6583, real_score: 0.8912, fake_score: 0.0839
# Saving 0896.png
# Epoch [897/1000], loss_g: 2.3133, loss_d: 0.6595, real_score: 0.8910, fake_score: 0.1073
# Saving 0897.png
# Epoch [898/1000], loss_g: 2.3346, loss_d: 0.6585, real_score: 0.8835, fake_score: 0.1022
# Saving 0898.png
# Epoch [899/1000], loss_g: 2.4398, loss_d: 0.6576, real_score: 0.9048, fake_score: 0.0963
# Saving 0899.png
# Epoch [900/1000], loss_g: 2.5545, loss_d: 0.6604, real_score: 0.9014, fake_score: 0.1096
# Saving 0900.png
# Epoch [901/1000], loss_g: 2.3758, loss_d: 0.6636, real_score: 0.8791, fake_score: 0.1084
# Saving 0901.png
# Epoch [902/1000], loss_g: 2.3884, loss_d: 0.6586, real_score: 0.8913, fake_score: 0.0908
# Saving 0902.png
# Epoch [903/1000], loss_g: 2.1341, loss_d: 0.6707, real_score: 0.8644, fake_score: 0.0678
# Saving 0903.png
# Epoch [904/1000], loss_g: 2.4380, loss_d: 0.6581, real_score: 0.8963, fake_score: 0.1110
# Saving 0904.png
# Epoch [905/1000], loss_g: 2.4597, loss_d: 0.6594, real_score: 0.8973, fake_score: 0.1171
# Saving 0905.png
# Epoch [906/1000], loss_g: 2.2282, loss_d: 0.6603, real_score: 0.8869, fake_score: 0.0788
# Saving 0906.png
# Epoch [907/1000], loss_g: 2.2853, loss_d: 0.6573, real_score: 0.9038, fake_score: 0.1101
# Saving 0907.png
# Epoch [908/1000], loss_g: 2.1688, loss_d: 0.6900, real_score: 0.8375, fake_score: 0.0579
# Saving 0908.png
# Epoch [909/1000], loss_g: 2.5279, loss_d: 0.6595, real_score: 0.8921, fake_score: 0.1149
# Saving 0909.png
# Epoch [910/1000], loss_g: 2.3975, loss_d: 0.6572, real_score: 0.8964, fake_score: 0.1006
# Saving 0910.png
# Epoch [911/1000], loss_g: 2.5077, loss_d: 0.6584, real_score: 0.9064, fake_score: 0.1171
# Saving 0911.png
# Epoch [912/1000], loss_g: 2.2983, loss_d: 0.6716, real_score: 0.9273, fake_score: 0.1348
# Saving 0912.png
# Epoch [913/1000], loss_g: 2.5134, loss_d: 0.6624, real_score: 0.9060, fake_score: 0.1175
# Saving 0913.png
# Epoch [914/1000], loss_g: 2.4514, loss_d: 0.6592, real_score: 0.9056, fake_score: 0.1049
# Saving 0914.png
# Epoch [915/1000], loss_g: 2.3886, loss_d: 0.6578, real_score: 0.9082, fake_score: 0.1122
# Saving 0915.png
# Epoch [916/1000], loss_g: 2.2157, loss_d: 0.6592, real_score: 0.8753, fake_score: 0.1004
# Saving 0916.png
# Epoch [917/1000], loss_g: 2.3892, loss_d: 0.6564, real_score: 0.9047, fake_score: 0.1131
# Saving 0917.png
# Epoch [918/1000], loss_g: 2.2212, loss_d: 0.6559, real_score: 0.9019, fake_score: 0.0863
# Saving 0918.png
# Epoch [919/1000], loss_g: 2.0369, loss_d: 0.6654, real_score: 0.8663, fake_score: 0.0818
# Saving 0919.png
# Epoch [920/1000], loss_g: 2.2332, loss_d: 0.6603, real_score: 0.8912, fake_score: 0.0800
# Saving 0920.png
# Epoch [921/1000], loss_g: 2.2646, loss_d: 0.6634, real_score: 0.8752, fake_score: 0.1015
# Saving 0921.png
# Epoch [922/1000], loss_g: 2.3608, loss_d: 0.6580, real_score: 0.8931, fake_score: 0.1096
# Saving 0922.png
# Epoch [923/1000], loss_g: 2.3217, loss_d: 0.6658, real_score: 0.8713, fake_score: 0.0717
# Saving 0923.png
# Epoch [924/1000], loss_g: 2.6707, loss_d: 0.6683, real_score: 0.9262, fake_score: 0.1309
# Saving 0924.png
# Epoch [925/1000], loss_g: 2.0650, loss_d: 0.6631, real_score: 0.8696, fake_score: 0.0930
# Saving 0925.png
# Epoch [926/1000], loss_g: 2.6701, loss_d: 0.6600, real_score: 0.8973, fake_score: 0.1049
# Saving 0926.png
# Epoch [927/1000], loss_g: 2.2861, loss_d: 0.6607, real_score: 0.8946, fake_score: 0.1168
# Saving 0927.png
# Epoch [928/1000], loss_g: 2.2125, loss_d: 0.6675, real_score: 0.8665, fake_score: 0.0774
# Saving 0928.png
# Epoch [929/1000], loss_g: 2.1194, loss_d: 0.6613, real_score: 0.8774, fake_score: 0.0871
# Saving 0929.png
# Epoch [930/1000], loss_g: 2.4547, loss_d: 0.6609, real_score: 0.8893, fake_score: 0.0856
# Saving 0930.png
# Epoch [931/1000], loss_g: 1.9029, loss_d: 0.6797, real_score: 0.8413, fake_score: 0.0654
# Saving 0931.png
# Epoch [932/1000], loss_g: 2.2702, loss_d: 0.6642, real_score: 0.8815, fake_score: 0.0859
# Saving 0932.png
# Epoch [933/1000], loss_g: 2.0366, loss_d: 0.6616, real_score: 0.8768, fake_score: 0.0987
# Saving 0933.png
# Epoch [934/1000], loss_g: 2.1002, loss_d: 0.6596, real_score: 0.8752, fake_score: 0.0885
# Saving 0934.png
# Epoch [935/1000], loss_g: 2.3914, loss_d: 0.6568, real_score: 0.8889, fake_score: 0.1034
# Saving 0935.png
# Epoch [936/1000], loss_g: 2.9231, loss_d: 0.6645, real_score: 0.9214, fake_score: 0.1332
# Saving 0936.png
# Epoch [937/1000], loss_g: 2.4732, loss_d: 0.6580, real_score: 0.9051, fake_score: 0.1102
# Saving 0937.png
# Epoch [938/1000], loss_g: 2.2696, loss_d: 0.6593, real_score: 0.9019, fake_score: 0.0965
# Saving 0938.png
# Epoch [939/1000], loss_g: 2.4914, loss_d: 0.6595, real_score: 0.8931, fake_score: 0.1183
# Saving 0939.png
# Epoch [940/1000], loss_g: 2.2193, loss_d: 0.6701, real_score: 0.8614, fake_score: 0.0790
# Saving 0940.png
# Epoch [941/1000], loss_g: 2.6822, loss_d: 0.6719, real_score: 0.9291, fake_score: 0.1348
# Saving 0941.png
# Epoch [942/1000], loss_g: 2.3022, loss_d: 0.6628, real_score: 0.8861, fake_score: 0.0811
# Saving 0942.png
# Epoch [943/1000], loss_g: 2.2138, loss_d: 0.7032, real_score: 0.8461, fake_score: 0.0419
# Saving 0943.png
# Epoch [944/1000], loss_g: 2.1746, loss_d: 0.6597, real_score: 0.8847, fake_score: 0.0940
# Saving 0944.png
# Epoch [945/1000], loss_g: 2.3013, loss_d: 0.6588, real_score: 0.8916, fake_score: 0.1045
# Saving 0945.png
# Epoch [946/1000], loss_g: 2.2140, loss_d: 0.6581, real_score: 0.8871, fake_score: 0.1003
# Saving 0946.png
# Epoch [947/1000], loss_g: 2.5342, loss_d: 0.6613, real_score: 0.9038, fake_score: 0.1161
# Saving 0947.png
# Epoch [948/1000], loss_g: 3.1583, loss_d: 0.6770, real_score: 0.9166, fake_score: 0.1637
# Saving 0948.png
# Epoch [949/1000], loss_g: 2.2368, loss_d: 0.6642, real_score: 0.8689, fake_score: 0.0964
# Saving 0949.png
# Epoch [950/1000], loss_g: 2.1153, loss_d: 0.6612, real_score: 0.8758, fake_score: 0.1059
# Saving 0950.png
# Epoch [951/1000], loss_g: 2.1728, loss_d: 0.6639, real_score: 0.8803, fake_score: 0.0778
# Saving 0951.png
# Epoch [952/1000], loss_g: 2.4295, loss_d: 0.6582, real_score: 0.8992, fake_score: 0.0948
# Saving 0952.png
# Epoch [953/1000], loss_g: 2.2643, loss_d: 0.6596, real_score: 0.8907, fake_score: 0.1090
# Saving 0953.png
# Epoch [954/1000], loss_g: 2.0223, loss_d: 0.6622, real_score: 0.8703, fake_score: 0.0849
# Saving 0954.png
# Epoch [955/1000], loss_g: 2.2538, loss_d: 0.6591, real_score: 0.8899, fake_score: 0.1069
# Saving 0955.png
# Epoch [956/1000], loss_g: 2.2572, loss_d: 0.6729, real_score: 0.8639, fake_score: 0.0666
# Saving 0956.png
# Epoch [957/1000], loss_g: 2.4578, loss_d: 0.6608, real_score: 0.9021, fake_score: 0.1110
# Saving 0957.png
# Epoch [958/1000], loss_g: 2.0463, loss_d: 0.6649, real_score: 0.8656, fake_score: 0.0842
# Saving 0958.png
# Epoch [959/1000], loss_g: 2.3329, loss_d: 0.6578, real_score: 0.8923, fake_score: 0.1064
# Saving 0959.png
# Epoch [960/1000], loss_g: 1.9736, loss_d: 0.6654, real_score: 0.8626, fake_score: 0.0897
# Saving 0960.png
# Epoch [961/1000], loss_g: 2.9174, loss_d: 0.6745, real_score: 0.9185, fake_score: 0.1562
# Saving 0961.png
# Epoch [962/1000], loss_g: 3.0884, loss_d: 0.6793, real_score: 0.9311, fake_score: 0.1589
# Saving 0962.png
# Epoch [963/1000], loss_g: 2.3605, loss_d: 0.6580, real_score: 0.9016, fake_score: 0.1068
# Saving 0963.png
# Epoch [964/1000], loss_g: 2.7268, loss_d: 0.6715, real_score: 0.9178, fake_score: 0.1422
# Saving 0964.png
# Epoch [965/1000], loss_g: 2.3612, loss_d: 0.6581, real_score: 0.9019, fake_score: 0.1105
# Saving 0965.png
# Epoch [966/1000], loss_g: 2.7287, loss_d: 0.6818, real_score: 0.8941, fake_score: 0.1404
# Saving 0966.png
# Epoch [967/1000], loss_g: 2.5426, loss_d: 0.6937, real_score: 0.8585, fake_score: 0.0921
# Saving 0967.png
# Epoch [968/1000], loss_g: 2.0135, loss_d: 0.6711, real_score: 0.8873, fake_score: 0.1057
# Saving 0968.png
# Epoch [969/1000], loss_g: 2.5233, loss_d: 0.6677, real_score: 0.9068, fake_score: 0.1332
# Saving 0969.png
# Epoch [970/1000], loss_g: 2.5233, loss_d: 0.6643, real_score: 0.8982, fake_score: 0.1193
# Saving 0970.png
# Epoch [971/1000], loss_g: 2.1637, loss_d: 0.6669, real_score: 0.8703, fake_score: 0.0799
# Saving 0971.png
# Epoch [972/1000], loss_g: 2.7629, loss_d: 0.6706, real_score: 0.9148, fake_score: 0.1455
# Saving 0972.png
# Epoch [973/1000], loss_g: 2.4337, loss_d: 0.6631, real_score: 0.8915, fake_score: 0.1283
# Saving 0973.png
# Epoch [974/1000], loss_g: 2.3227, loss_d: 0.6586, real_score: 0.8860, fake_score: 0.0832
# Saving 0974.png
# Epoch [975/1000], loss_g: 2.5520, loss_d: 0.6622, real_score: 0.9059, fake_score: 0.1296
# Saving 0975.png
# Epoch [976/1000], loss_g: 2.1633, loss_d: 0.6600, real_score: 0.8762, fake_score: 0.0950
# Saving 0976.png
# Epoch [977/1000], loss_g: 2.0414, loss_d: 0.6696, real_score: 0.8617, fake_score: 0.0781
# Saving 0977.png
# Epoch [978/1000], loss_g: 2.3296, loss_d: 0.6606, real_score: 0.8975, fake_score: 0.1181
# Saving 0978.png
# Epoch [979/1000], loss_g: 2.2689, loss_d: 0.6583, real_score: 0.9022, fake_score: 0.1001
# Saving 0979.png
# Epoch [980/1000], loss_g: 2.5914, loss_d: 0.6585, real_score: 0.8862, fake_score: 0.1104
# Saving 0980.png
# Epoch [981/1000], loss_g: 2.2507, loss_d: 0.6578, real_score: 0.8912, fake_score: 0.0973
# Saving 0981.png
# Epoch [982/1000], loss_g: 3.0538, loss_d: 0.6788, real_score: 0.9297, fake_score: 0.1577
# Saving 0982.png
# Epoch [983/1000], loss_g: 3.0519, loss_d: 0.6844, real_score: 0.9336, fake_score: 0.1649
# Saving 0983.png
# Epoch [984/1000], loss_g: 2.2673, loss_d: 0.6593, real_score: 0.8927, fake_score: 0.0962
# Saving 0984.png
# Epoch [985/1000], loss_g: 2.4502, loss_d: 0.6587, real_score: 0.9019, fake_score: 0.0995
# Saving 0985.png
# Epoch [986/1000], loss_g: 2.2832, loss_d: 0.6577, real_score: 0.8948, fake_score: 0.1010
# Saving 0986.png
# Epoch [987/1000], loss_g: 2.2526, loss_d: 0.6706, real_score: 0.8690, fake_score: 0.0647
# Saving 0987.png
# Epoch [988/1000], loss_g: 2.5273, loss_d: 0.6605, real_score: 0.9110, fake_score: 0.1285
# Saving 0988.png
# Epoch [989/1000], loss_g: 2.4318, loss_d: 0.6582, real_score: 0.8999, fake_score: 0.1198
# Saving 0989.png
# Epoch [990/1000], loss_g: 2.4103, loss_d: 0.6578, real_score: 0.9025, fake_score: 0.1165
# Saving 0990.png
# Epoch [991/1000], loss_g: 2.7718, loss_d: 0.6633, real_score: 0.9121, fake_score: 0.1370
# Saving 0991.png
# Epoch [992/1000], loss_g: 2.3891, loss_d: 0.6571, real_score: 0.8979, fake_score: 0.1092
# Saving 0992.png
# Epoch [993/1000], loss_g: 3.0015, loss_d: 0.6704, real_score: 0.9186, fake_score: 0.1515
# Saving 0993.png
# Epoch [994/1000], loss_g: 2.2680, loss_d: 0.6576, real_score: 0.8894, fake_score: 0.0866
# Saving 0994.png
# Epoch [995/1000], loss_g: 2.6013, loss_d: 0.6677, real_score: 0.9224, fake_score: 0.1327
# Saving 0995.png
# Epoch [996/1000], loss_g: 2.1017, loss_d: 0.6584, real_score: 0.8815, fake_score: 0.0986
# Saving 0996.png
# Epoch [997/1000], loss_g: 2.0042, loss_d: 0.6634, real_score: 0.8682, fake_score: 0.0907
# Saving 0997.png
# Epoch [998/1000], loss_g: 2.6507, loss_d: 0.6610, real_score: 0.9113, fake_score: 0.1077
# Saving 0998.png
# Epoch [999/1000], loss_g: 2.7219, loss_d: 0.6738, real_score: 0.9274, fake_score: 0.1397
# Saving 0999.png
# Epoch [1000/1000], loss_g: 2.6277, loss_d: 0.6583, real_score: 0.8967, fake_score: 0.1013
# Saving 1000.png

# %%
losses_g, losses_d, real_scores, fake_scores = history

# %%
pwd
# Out:
# '/content'

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/generated/0999.png')

# %%
plt.plot(losses_d, '-')
plt.plot(losses_g, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real', 'Fake'])
plt.title('Scores');

# %%
# !pip install imageio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio in /usr/local/lib/python3.8/dist-packages (2.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from imageio) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from imageio) (7.1.2)

# %%
import imageio
import glob

# %%
anim_file = 'gan_pokemon.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('/content/drive/MyDrive/generated/*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):
      last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

import IPython
from IPython import display
if IPython.version_info > (6,2,0,''):
  display.Image(filename=anim_file)

# %%
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download(anim_file)
